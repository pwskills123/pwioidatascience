# %%
import pandas as pd

# %%
pd.__version__ # To print the installed vesion pandas
# Out:
# '1.4.2'

# %%
games=pd.read_csv("vgsalesGlobale.csv")

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# games.head()

'''

This function returns the first `n` rows for the object based
on position. It is useful for quickly testing if your object
has the right type of data in it.


'''
# Out:
# '\n\nThis function returns the first `n` rows for the object based\non position. It is useful for quickly testing if your object\nhas the right type of data in it.\n\n\n'

# %%
games.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
games.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
games.Genre
# Out:
# 0              Sports
# 1            Platform
# 2              Racing
# 3              Sports
# 4        Role-Playing
#              ...
# 16593        Platform
# 16594         Shooter
# 16595          Racing
# 16596          Puzzle
# 16597        Platform
# Name: Genre, Length: 16598, dtype: object

# %%
games['Genre']
# Out:
# 0              Sports
# 1            Platform
# 2              Racing
# 3              Sports
# 4        Role-Playing
#              ...
# 16593        Platform
# 16594         Shooter
# 16595          Racing
# 16596          Puzzle
# 16597        Platform
# Name: Genre, Length: 16598, dtype: object

# %%
games.Genre.describe()
# Out:
# count      16598
# unique        12
# top       Action
# freq        3316
# Name: Genre, dtype: object

# %%
games.Genre.value_counts() 

# Return a Series containing counts of unique values
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
games.Genre.value_counts(normalize=True)
# Out:
# Action          0.199783
# Sports          0.141342
# Misc            0.104772
# Role-Playing    0.089649
# Shooter         0.078925
# Adventure       0.077479
# Racing          0.075250
# Platform        0.053380
# Simulation      0.052235
# Fighting        0.051090
# Strategy        0.041029
# Puzzle          0.035064
# Name: Genre, dtype: float64

# %% [markdown]
# relative frequency = f / n

# %% [markdown]
# 1. f is the number of times the data occurred in an observation
#
# 2. total frequency

# %%
type(games.Genre.value_counts())
# Out:
# pandas.core.series.Series

# %%
games.Genre.value_counts().head()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Name: Genre, dtype: int64

# %%
games.Genre.unique()

# Return unique values of Series object
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
games.Genre.nunique()

# Return number of unique elements in the object
# Out:
# 12

# %% [markdown]
# Compute a simple cross tabulation of two (or more) factors. By default
# computes a frequency table of the factors unless an array of values and an
# aggregation function are passed.

# %%
pd.crosstab(games.Genre, games.Year)
# This function allows you to compute a frequency table of two or more variables
# Out:
# Year          1980.0  1981.0  1982.0  1983.0  1984.0  1985.0  1986.0  1987.0  \
# Genre
# Action             1      25      18       7       1       2       6       2
# Adventure          0       0       0       1       0       0       0       1
# Fighting           1       0       0       0       0       1       0       2
# Misc               4       0       1       1       1       0       0       0
# Platform           0       3       5       5       1       4       6       2
# Puzzle             0       2       3       1       3       4       0       0
# Racing             0       1       2       0       3       0       1       0
# Role-Playing       0       0       0       0       0       0       1       3
# Shooter            2      10       5       1       3       1       4       2
# Simulation         0       1       0       0       0       1       0       0
# Sports             1       4       2       1       2       1       3       4
# ...

# %%
# create a sample dataset
df = pd.DataFrame({
    'gender': ['male', 'male', 'female', 'female', 'male', 'female', 'male', 'female'],
    'education_level': ['high school', 'college', 'college', 'graduate', 'high school', 'graduate', 'college', 'graduate'],
    'score': [75, 82, 88, 95, 69, 92, 78, 85]
})

# create a crosstab table of gender and education level
ct = pd.crosstab(df['gender'], df['education_level'])
print(ct)
# Out:
# education_level  college  graduate  high school
# gender
# female                 1         3            0
# male                   2         0            2

# %%
# Aggregating Values in Crosstab Table

# %%
# create a crosstab table of gender and education level with mean score
ct_mean = pd.crosstab(df['gender'], df['education_level'], 
                    values=df['score'], aggfunc='mean')
print(ct_mean)
# Out:
# education_level  college   graduate  high school
# gender
# female              88.0  90.666667          NaN
# male                80.0        NaN         72.0

# %%
# create a crosstab table of gender and education level with normalization
ct_norm = pd.crosstab(df['gender'], df['education_level'], normalize=True,
                      margins=True)
print(ct_norm)
# Out:
# education_level  college  graduate  high school  All
# gender
# female             0.125     0.375         0.00  0.5
# male               0.250     0.000         0.25  0.5
# All                0.375     0.375         0.25  1.0

# %%
# create a crosstab table of gender and education level with visualization
ct_viz = pd.crosstab(df['gender'], df['education_level'])
ct_viz.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
games.Global_Sales.describe()
# Out:
# count    16598.000000
# mean         0.537441
# std          1.555028
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.470000
# max         82.740000
# Name: Global_Sales, dtype: float64

# %%
games.Global_Sales.mean()
# Out:
# 0.53744065550074

# %%
games.Global_Sales.value_counts()
# Out:
# 0.02    1071
# 0.03     811
# 0.04     645
# 0.05     632
# 0.01     618
#         ...
# 5.01       1
# 5.05       1
# 5.07       1
# 5.11       1
# 3.16       1
# Name: Global_Sales, Length: 623, dtype: int64

# %%
games.Year.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
games.Genre.value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
games.Genre.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
data={"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],      
      "score":[90,80,85,75,95,60,65],      
      "sport":["Wrestling","Football","Skiing","Swimming","Tennis",
               "Karete","Surfing"],      
      "gender":["M","M","M","M","F","F","F"]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       name  score      sport gender
# 0     Bill     90  Wrestling      M
# 1      Tom     80   Football      M
# 2      Tim     85     Skiing      M
# 3     John     75   Swimming      M
# 4     Alex     95     Tennis      F
# 5  Vanessa     60     Karete      F
# 6     Kate     65    Surfing      F

# %%
df=pd.DataFrame(data,columns=["name","sport","gender","score"])
df
# Out:
#       name      sport gender  score
# 0     Bill  Wrestling      M     90
# 1      Tom   Football      M     80
# 2      Tim     Skiing      M     85
# 3     John   Swimming      M     75
# 4     Alex     Tennis      F     95
# 5  Vanessa     Karete      F     60
# 6     Kate    Surfing      F     65

# %%
df.head()
# Out:
#    name      sport gender  score
# 0  Bill  Wrestling      M     90
# 1   Tom   Football      M     80
# 2   Tim     Skiing      M     85
# 3  John   Swimming      M     75
# 4  Alex     Tennis      F     95

# %%
df.tail()
# Out:
#       name     sport gender  score
# 2      Tim    Skiing      M     85
# 3     John  Swimming      M     75
# 4     Alex    Tennis      F     95
# 5  Vanessa    Karete      F     60
# 6     Kate   Surfing      F     65

# %%
df.tail(3)
# Out:
#       name    sport gender  score
# 4     Alex   Tennis      F     95
# 5  Vanessa   Karete      F     60
# 6     Kate  Surfing      F     65

# %%
df.head(2)
# Out:
#    name      sport gender  score
# 0  Bill  Wrestling      M     90
# 1   Tom   Football      M     80

# %%
df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"])
df
# Out:
#       name      sport gender  score  age
# 0     Bill  Wrestling      M     90  NaN
# 1      Tom   Football      M     80  NaN
# 2      Tim     Skiing      M     85  NaN
# 3     John   Swimming      M     75  NaN
# 4     Alex     Tennis      F     95  NaN
# 5  Vanessa     Karete      F     60  NaN
# 6     Kate    Surfing      F     65  NaN

# %%
df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"],
                index=["one","two","three","four","five","six","seven"])
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling      M     90  NaN
# two        Tom   Football      M     80  NaN
# three      Tim     Skiing      M     85  NaN
# four      John   Swimming      M     75  NaN
# five      Alex     Tennis      F     95  NaN
# six    Vanessa     Karete      F     60  NaN
# seven     Kate    Surfing      F     65  NaN

# %%
df["sport"]
# Out:
# one      Wrestling
# two       Football
# three       Skiing
# four      Swimming
# five        Tennis
# six         Karete
# seven      Surfing
# Name: sport, dtype: object

# %%
my_columns=["name","sport"]
df[my_columns]
# Out:
#           name      sport
# one       Bill  Wrestling
# two        Tom   Football
# three      Tim     Skiing
# four      John   Swimming
# five      Alex     Tennis
# six    Vanessa     Karete
# seven     Kate    Surfing

# %%
df.sport
# Out:
# one      Wrestling
# two       Football
# three       Skiing
# four      Swimming
# five        Tennis
# six         Karete
# seven      Surfing
# Name: sport, dtype: object

# %% [markdown]
# Using the iloc[] or loc[] attribute: The iloc[] and loc[] attributes allow you to access rows and columns of a DataFrame using integer positions or labels, respectively. To access the row index of a specific row, use the iloc[] or loc[] attribute and pass the row position or label as the argument.

# %% [markdown]
# iloc: Stands for Integer Location
#
# 1. It is used for integer-location based indexing.
# 2. It is primarily integer-based and is used when you want to select data by integer index positions.
# 3. The syntax for using iloc is df.iloc[row_index, column_index]
#
# loc: Stands for Label Location
#
# 1. It is used for label-based indexing.
# 2. It is primarily label-based and is used when you want to select data by labels (row and column names).
# 3. The syntax for using loc is df.loc[row_label, column_label].

# %% [markdown]
# ![ilocandloc.png](attachment:ilocandloc.png)

# %%
df.loc[["one"]]
# Out:
#      name      sport gender  score  age
# one  Bill  Wrestling      M     90  NaN

# %%
df.loc[["one","two"]]
# Out:
#      name      sport gender  score  age
# one  Bill  Wrestling      M     90  NaN
# two   Tom   Football      M     80  NaN

# %%
df["age"]=18

# %%
df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"], 
                index=["one","two","three","four","five","six","seven"])
values=[18,19,20,18,17,17,18]
df["age"]=values
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling      M     90   18
# two        Tom   Football      M     80   19
# three      Tim     Skiing      M     85   20
# four      John   Swimming      M     75   18
# five      Alex     Tennis      F     95   17
# six    Vanessa     Karete      F     60   17
# seven     Kate    Surfing      F     65   18

# %%
df["pass"]=df.score>=70
df
# Out:
#           name      sport gender  score  age   pass
# one       Bill  Wrestling      M     90   18   True
# two        Tom   Football      M     80   19   True
# three      Tim     Skiing      M     85   20   True
# four      John   Swimming      M     75   18   True
# five      Alex     Tennis      F     95   17   True
# six    Vanessa     Karete      F     60   17  False
# seven     Kate    Surfing      F     65   18  False

# %%
del df["pass"]
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling      M     90   18
# two        Tom   Football      M     80   19
# three      Tim     Skiing      M     85   20
# four      John   Swimming      M     75   18
# five      Alex     Tennis      F     95   17
# six    Vanessa     Karete      F     60   17
# seven     Kate    Surfing      F     65   18

# %%
scores={"Math":{"A":85,"B":90,"C":95}, "Physics":{"A":90,"B":80,"C":75}}

# %%
scores_df=pd.DataFrame(scores)
scores_df
# Out:
#    Math  Physics
# A    85       90
# B    90       80
# C    95       75

# %%
scores_df.T
# Out:
#           A   B   C
# Math     85  90  95
# Physics  90  80  75

# %%
scores_df.index.name="name"
scores_df.columns.name="lesson"

# %%
scores_df
# Out:
# lesson  Math  Physics
# name
# A         85       90
# B         90       80
# C         95       75

# %%
scores_df.values
# Out:
# array([[85, 90],
#        [90, 80],
#        [95, 75]], dtype=int64)

# %%
scores_index=scores_df.index

# %%
#scores_index[1]="Jack"
# error
scores_index
# Out:
# Index(['A', 'B', 'C'], dtype='object', name='name')

# %% [markdown]
# # Indexing & Selection & Filtering in Pandas

# %%
obj=pd.Series(np.arange(5),
              index=["a","b","c","d","e"])

# %%
obj
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int32

# %%
obj["c"]
# Out:
# 2

# %%
obj[2]
# Out:
# 2

# %%
obj[0:3]
# Out:
# a    0
# b    1
# c    2
# dtype: int32

# %% [markdown]
# ![iotoolsimage.png](attachment:iotoolsimage.png)

# %% [markdown]
# # CSV & text files

# %%
import pandas as pd

# %%
#Example 1
df=pd.read_csv('cardekho_dataset.csv')

# %%
df
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
#example 2
df1=pd.read_csv('COVID19Cases.csv')
# Out:
# C:\Users\imran\AppData\Local\Temp\ipykernel_31784\3099355423.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv('COVID19Cases.csv')

# %%
df1
# Out:
#         Case_Type  People_Total_Tested_Count  Cases  Difference       Date  \
# 0       Confirmed                        NaN      6           0  5/22/2020
# 1       Confirmed                        NaN      0           0   2/3/2020
# 2          Deaths                        NaN      0           0   3/1/2020
# 3       Confirmed                        NaN     23           0  4/21/2020
# 4          Deaths                        NaN     56           0  5/11/2020
# ...           ...                        ...    ...         ...        ...
# 950665     Deaths                        NaN      0           0  1/22/2020
# 950666  Confirmed                        NaN      0           0  1/22/2020
# 950667     Deaths                        NaN      0           0  1/22/2020
# 950668  Confirmed                        NaN      0           0  1/22/2020
# 950669  Confirmed                        NaN      0           0  1/22/2020
#
# ...

# %% [markdown]
# # Reading JSON

# %%
df=pd.read_json('unece.json')

# %%
df
# Out:
#         Country  Year  Area (square kilometres)  Total population  \
# 0       Albania  2000                   28748.0         3401198.0
# 1       Albania  2001                   28748.0         3073734.0
# 2       Albania  2002                   28748.0         3093465.0
# 3       Albania  2003                   28748.0         3111162.0
# 4       Albania  2004                   28748.0         3127264.0
# ..          ...   ...                       ...               ...
# 879  Uzbekistan  2012                  447400.0        29774448.0
# 880  Uzbekistan  2013                  447400.0        30243172.0
# 881  Uzbekistan  2014                  447400.0        30757669.0
# 882  Uzbekistan  2015                  447400.0        31298929.0
# 883  Uzbekistan  2016                  447400.0               NaN
#
#      Population density, pers. per sq. km  Population aged 0-14, male  \
# 0                               118.31077                    564851.0
# ...

# %% [markdown]
# # Read Excel

# %%
df1=pd.read_excel('SampleSuperstore.xlsx')
# Out:
# C:\Users\imran\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df1
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 1          2  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 2          3  CA-2018-138688 2018-06-12 2018-06-16    Second Class
# 3          4  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# 4          5  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2016-110422 2016-01-21 2016-01-23    Second Class
# 9990    9991  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9991    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9992    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9993    9994  CA-2019-119914 2019-05-04 2019-05-09    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df2=pd.read_excel('SampleSuperstore.xlsx',sheet_name='People')
# Out:
# C:\Users\imran\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df2
# Out:
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
df3=pd.read_excel('SampleSuperstore.xlsx',sheet_name='Returns')
# Out:
# C:\Users\imran\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df3
# Out:
#     Returned        Order ID
# 0        Yes  CA-2016-100762
# 1        Yes  CA-2016-100762
# 2        Yes  CA-2016-100762
# 3        Yes  CA-2016-100762
# 4        Yes  CA-2016-100867
# ..       ...             ...
# 795      Yes  US-2019-147886
# 796      Yes  US-2019-147998
# 797      Yes  US-2019-151127
# 798      Yes  US-2019-155999
# 799      Yes  US-2019-155999
#
# [800 rows x 2 columns]

# %% [markdown]
# # Access from github

# %%
#link

# https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/phones.csv

pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/phones.csv')
# Out:
#     id  contact_id  location_id  organization_id  service_id  country_prefix  \
# 0    1         NaN          1.0              NaN         NaN             NaN
# 1    2         NaN          1.0              NaN         NaN             NaN
# 2    3         NaN          2.0              NaN         NaN             NaN
# 3    4         NaN          2.0              NaN         NaN             NaN
# 4    5         NaN          3.0              NaN         NaN             NaN
# 5    6         NaN          3.0              NaN         NaN             NaN
# 6    7         NaN          4.0              NaN         NaN             NaN
# 7    8         NaN          4.0              NaN         NaN             NaN
# 8    9         NaN          5.0              NaN         NaN             NaN
# 9   10         NaN          5.0              NaN         NaN             NaN
# 10  11         NaN          6.0              NaN         NaN             NaN
# ...

# %%
# link
# https://www.basketball-reference.com/leagues/NBA_2015_totals.html

# %%
df=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# # Read html

# %% [markdown]
# The pandas read_html() function is a quick and convenient way to turn an HTML table into a pandas DataFrame. This function can be useful for quickly incorporating tables from various websites without figuring out how to scrape the site’s HTML. However, there can be some challenges in cleaning and formatting the data before analyzing it. In this article, I will discuss how to use pandas read_html() to read and clean several Wikipedia HTML tables so that you can use them for further numeric analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')

# %%
table_MN
# Out:
# [                                            Minnesota  \
#  0                                               State
#  1   .mw-parser-output .ib-settlement-cols{text-ali...
#  2   Nicknames: Land of 10,000 Lakes;North Star Sta...
#  3   Motto: L'Étoile du Nord (French: The Star of t...
#  4                           Anthem: "Hail! Minnesota"
#  5   Map of the United States with Minnesota highli...
#  6                                             Country
#  7                                    Before statehood
#  8                               Admitted to the Union
#  9                                             Capital
#  10                                       Largest city
#  11                       Largest county or equivalent
#  12                      Largest metro and urban areas
#  13                                         Government
#  14                                         • Governor
#  15                              • Lieutenant Governor
# ...
